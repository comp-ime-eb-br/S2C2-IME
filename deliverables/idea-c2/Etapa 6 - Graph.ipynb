# %% [markdown]
# # **IDEA-C2-Graph - STEP 6: CONCEPTUAL MODELING**
#
# ## etrieves the curated .JSOL file from Doccano to generate the RDF graph in .TTL format. From this TTL file it is possible to execute SPARQL queries, exploiting the properties of the C2RM metamodel. It also retrieves the lists of inferences from Etapa-5 Run NE + RE (IDEA-ETAPA 5-RodaModeloNEReRE.ipynb) to generate graph visualization and integrate it into IDEA-C2-KG.
#
# ### Date of Creation: 01-06-2024
# ### Last update: 03-13-2025
# ### Authors: Gustavo Danon e Jones.

# %%
# Access the Google Drive folder
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Library installation
# !pip3 install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# Library installation of RDF Graph
# !pip3 install rdflib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 7.5 MB/s eta 0:00:00
# ...

# %%
# Importing libraries
import re
import sys
import json

import os

sys.path.insert(0,'/content/drive/MyDrive/Doutorado/IDEA/Código-fonte/IME-23-24-PIBIT-gustavo-graph-v8/')
os.chdir('/content/drive/MyDrive/Doutorado/IDEA/Código-fonte/IME-23-24-PIBIT-gustavo-graph-v8/')

import rdflib

# Folder with the main source codes for processing and generating the RDF graph
from C2IME import *

# %% [markdown]
# ## Upload the curated doccano .jsonl file and generate IDEA-C2-KG (base)

# %%
# Upload the curated doccano .jsonl file and generate IDEA-C2-KG (base)
anotated_filename ='docs/corpus_completo_curado_17052025.jsonl'

g=graph_functions.run_anotated_file(anotated_filename)
graph_functions.salvar_graph_ttl(g, 'docs/corpus_completo_curado_17052025.ttl')
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# entities: SONAR
# entities: detecção
#  from_id:  1424497 to_id:  1424498
# entities: SONDA
# entities: massa
#  from_id:  1424499 to_id:  1424500
# entities: SONDA BATITERMOGRÁFICA
# entities: SONDA DE REABASTECIMENTO
# entities: Equipamento
# entities: combate
#  from_id:  1424502 to_id:  1424503
#  from_id:  1424502 to_id:  1424504
# entities: SONDAGEM AEROLÓGICA
# entities: SOPRO
# entities: onda de choque
#  from_id:  1424506 to_id:  1424507
# entities: SPAM
# entities: Mensagem
#  from_id:  1424508 to_id:  1424509
# entities: SUBÁREA
# entities: área
# entities: responsabilidade
# entities: segurança integrada
# entities: segurança
# entities: área
#  from_id:  1424510 to_id:  1424511
#  from_id:  1424510 to_id:  1424512
#  from_id:  1424510 to_id:  1424513
#  from_id:  1424510 to_id:  1424514
#  from_id:  1424510 to_id:  1424515
# entities: SUBÁREA DE APOIO LOGÍSTICO
# entities: batalhão
# ...

# %% [markdown]
# ## Interaction with IDEA-C2-KG

# %%
rdf_turtle='docs/ICEIS-2024-ARTIGO-GRAFO.ttl'
h=graph_functions.load_turtle_to_graph(rdf_turtle)
graph_functions.visualize_graph_rdf_turtle(h)

# %%
# terms_file ='/content/drive/MyDrive/Doutorado/IDEA/Código-fonte/IME-23-24-PIBIT-gustavo-graph-v8/output/entidades.txt'
# relations_file ='/content/drive/MyDrive/Doutorado/IDEA/Código-fonte/IME-23-24-PIBIT-gustavo-graph-v8/output/entidades.txt'
# text_file ='docs/trecho.txt'

i=8
j=36
nome_arquivo_base = 'EB20-MC-10.203-TRECHO'
while i<=j:
  text_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/" + nome_arquivo_base + str(i) + ".txt"
  terms_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/entidades.txt"
  relations_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/relations.txt"
  print(text_file)
  #g=graph_functions.run_files_input_files(terms_file, relations_file, text_file)
#graph_functions.visualize_graph_rdf_turtle(g)
  i+=1
# Out:
# /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/EB20-MC-10.203-TRECHO8.txt
# /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/EB20-MC-10.203-TRECHO9.txt
# /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/EB20-MC-10.203-TRECHO10.txt
# /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/EB20-MC-10.203-TRECHO11.txt
# /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/EB20-MC-10.203-TRECHO12.txt
# /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/EB20-MC-10.203-TRECHO13.txt
# /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/EB20-MC-10.203-TRECHO14.txt
# /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/EB20-MC-10.203-TRECHO15.txt
# /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/EB20-MC-10.203-TRECHO16.txt
# /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/EB20-MC-10.203-TRECHO17.txt
# ...

# %%
i=7
nome_arquivo_base = 'trecho'
#text_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/Trechos/" + nome_arquivo_base + str(i) + ".txt"
text_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/trecho7.txt"
terms_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/entidades7.txt"
relations_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/relations7.txt"
g=graph_functions.run_files_input_files(terms_file, relations_file, text_file)
graph_functions.visualize_graph_rdf_turtle(g)
# Out:
# terms_file: /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/entidades7.txt
# relations_file /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/relations7.txt
# text_file /content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/trecho7.txt
# ./output/output.jsonl
# ...

# %%
import re
import sys
import json

import os

sys.path.insert(0,'/content/drive/MyDrive/Doutorado/IDEA/Código-fonte/IME-23-24-PIBIT-gustavo-graph-v8/')
os.chdir('/content/drive/MyDrive/Doutorado/IDEA/Código-fonte/IME-23-24-PIBIT-gustavo-graph-v8/')

import rdflib

from C2IME import *

# %%
#text_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/" + nome_arquivo_base + str(i) + ".txt"
text_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/ieee_text_input.txt"
terms_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/ieee_entidades.txt"
relations_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/ieee_relations.txt"

g=graph_functions.run_files_input_files(terms_file, relations_file, text_file)
#g=graph_functions.cria_grafo_from_model(terms_file, relations_file)
graph_functions.visualize_graph_rdf_turtle(g)
#graph_functions.salvar_graph_ttl(g, '/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/idea-c2-kg.ttl')

# %%
terms_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/ieee_entidades.txt"
relations_file = "/content/drive/MyDrive/Doutorado/IDEA/importa_glossario/texts/ieee_relations2.txt"

entities = file_functions.text_to_list(terms_file)
relations = file_functions.text_to_list(relations_file)

g=graph_functions.cria_grafo_from_model(entities, relations)
graph_functions.visualize_graph_rdf_turtle(g)

file_saida ='docs/ieee_grafo_rdf.ttl'
graph_functions.salvar_graph_ttl(g, file_saida)

# %%
rdf_turtle='docs/corpus_completo_curado_21082024.ttl'
g=graph_functions.load_turtle_to_graph(rdf_turtle)
#graph_functions.visualize_graph_rdf_turtle(g)

# xlist=graph_functions.select_grafo(g,
#                                    'PREFIX c2rm: <http://idea-c2.org/c2rm/#> PREFIX cnt: <http://idea-c2.org/data/#> ',
#                                    '* ',
#                                    '?s rdf:type c2rm:entity; . ?s ?p ?o .  FILTER(REGEX(str(?s),"operacao_de_seguranca"))',
#                                    '?s')

# query = 'SELECT DISTINCT * '
# query = query + ' WHERE '
# query = query + ' { ?s rdf:type c2rm:entity; . ?s ?p ?o .  FILTER(REGEX(str(?s),"operacao_de_seguranca")) } '
# query = query + ' ORDER BY ?s'

query = ''
query = 'PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> '
query = query + ' PREFIX c2rm: <http://idea-c2.org/c2rm/#> '
query = query + ' PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>'
query = query + ' PREFIX cnt: <http://idea-c2.org/data/#>'

query = query + ' SELECT  ?s ?p ?o'
query = query + ' WHERE '
query = query + ' {'
query = query + '     {?s ?p ?o .'
query = query + '     ?s c2rm:capacity_of ?o .'
query = query + '     ?s1 rdf:type ?o .'
query = query + '     FILTER(?s=cnt:agentes_especiais)'
query = query + '     }'
query = query + ' UNION'
query = query + '     {?s ?p ?o . FILTER(?s=cnt:forca_adversa) }'
query = query + ' UNION'
query = query + ' {?s ?p ?o .'
query = query + '     FILTER(?s=cnt:agentes_armados)}    '
query = query + '  UNION'
query = query + ' {?s ?p ?o .'
query = query + '     FILTER(?s=cnt:militantes)}    '
query = query + ' }'

query = ''
query = 'PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> '
query = query + ' PREFIX c2rm: <http://idea-c2.org/c2rm/#> '
query = query + ' PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>'
query = query + ' PREFIX cnt: <http://idea-c2.org/data/#>'
query = query + ' SELECT  ?s ?p ?o'
query = query + ' WHERE '
query = query + ' {'
query = query + '     {?s ?p ?o .'
query = query + '     ?s c2rm:capacity_of ?o .'
query = query + '     ?s1 rdf:type ?o .'
query = query + '     FILTER(?s=cnt:agentes_especiais)'
query = query + '     }'
query = query + ' UNION'
query = query + '     {?s ?p ?o . FILTER(?s=cnt:forca_adversa) }'
query = query + ' UNION'
query = query + ' {?s ?p ?o .'
query = query + '     FILTER(?s=cnt:agentes_armados)}    '
query = query + '  UNION'
query = query + ' {?s ?p ?o .'
query = query + '     FILTER(?s=cnt:militantes)}    '
query = query + ' }'

xlist=graph_functions.select_grafo2(g, query)
g2=graph_functions.create_subgraph(xlist)
#graph_functions.visualize_graph_with_networkx(g2)
graph_functions.visualize_graph_rdf_turtle(g2)
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>  PREFIX c2rm: <http://idea-c2.org/c2rm/#>  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX cnt: <http://idea-c2.org/data/#> SELECT  ?s ?p ?o WHERE  {     {?s ?p ?o .     ?s c2rm:capacity_of ?o .     ?s1 rdf:type ?o .     FILTER(?s=cnt:agentes_especiais)     } UNION     {?s ?p ?o . FILTER(?s=cnt:forca_adversa) } UNION {?s ?p ?o .     FILTER(?s=cnt:agentes_armados)}      UNION {?s ?p ?o .     FILTER(?s=cnt:militantes)}     }
# http://idea-c2.org/data/#agentes_especiais http://idea-c2.org/c2rm/#capacity_of http://idea-c2.org/data/#atividades_especificas
# http://idea-c2.org/data/#agentes_especiais http://idea-c2.org/c2rm/#capacity_of http://idea-c2.org/data/#atividades_especificas
# http://idea-c2.org/data/#forca_adversa http://www.w3.org/2000/01/rdf-schema#seeAlso http://idea-c2.org/data/#braco_armado
# ...

# %%
print(query)
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>  PREFIX c2rm: <http://idea-c2.org/c2rm/#>  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX cnt: <http://idea-c2.org/data/#> SELECT  ?s ?p ?o WHERE  {     {?s ?p ?o .     ?s c2rm:capacity_of ?o .     ?s1 rdf:type ?o .     FILTER(?s=cnt:agentes_especiais)     } UNION     {?s ?p ?o .     FILTER(?s=cnt:forca_adversa)     } UNION {?s ?p ?o .     FILTER(?s=cnt:agentes_armados)}      UNION {?s ?p ?o .     FILTER(?s=cnt:militantes)}     }

# %% [markdown]
# # Consulta do artigo da IEEE Latin American

# %%
rdf_turtle='docs/ieee_grafo_rdf_2.ttl'
h=graph_functions.load_turtle_to_graph(rdf_turtle)
graph_functions.visualize_graph_rdf_turtle(h)

# %%
import re
import sys
import json

import os

sys.path.insert(0,'/content/drive/MyDrive/Doutorado/IDEA/Código-fonte/IME-23-24-PIBIT-gustavo-graph-v8/')
os.chdir('/content/drive/MyDrive/Doutorado/IDEA/Código-fonte/IME-23-24-PIBIT-gustavo-graph-v8/')

import rdflib

from C2IME import *

# %%
rdf_turtle='docs/corpus_completo_curado_17052025.ttl'
g=graph_functions.load_turtle_to_graph(rdf_turtle)

query = ''
query = 'PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> '
query = query + ' PREFIX c2rm: <http://idea-c2.org/c2rm/#> '
query = query + ' PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> '
query = query + ' PREFIX cnt: <http://idea-c2.org/data/#> '
query = query + ' SELECT DISTINCT ?opcj ?p ?level ?org ?p3 ?level ?level ?p4 ?slevel'
query = query + ' WHERE '
query = query + ' {'
query = query + '   ?opcj ?p ?level  .'
query = query + '   ?opcj c2rm:applied_to ?level  . '
query = query + '   ?org ?p3 ?level . '
query = query + '   ?org c2rm:responsible_for ?level . '
query = query + '   ?level ?p4 ?agency . '
query = query + '   ?org rdfs:subClassOf ?agency  '
query = query + '   FILTER(?opcj=cnt:operacao_conjunta) . '
#query = query + '   FILTER(REGEX(str(?opcj),"operacao_conjunta")) . '
query = query + ' }'
#query = query + ' LIMIT 1'

# ?s ?p ?o .'
# query = query + '     ?s c2rm:capacity_of ?o .'
# query = query + '     ?s1 rdf:type ?o .'
# query = query + '     FILTER(?s=cnt:agentes_especiais)'

# select=[]
# select[0] = "s p o"
# select

print(query)


xlist=graph_functions.select_grafo3(g, query)
g2=graph_functions.create_subgraph(xlist)
# graph_functions.visualize_graph_with_networkx(g2)
graph_functions.visualize_graph_rdf_turtle(g2)

#file_saida ='docs/ieee_grafo_rdf_sparql.ttl'
#graph_functions.salvar_graph_ttl(g2, file_saida)
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>  PREFIX c2rm: <http://idea-c2.org/c2rm/#>  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>  PREFIX cnt: <http://idea-c2.org/data/#>  SELECT DISTINCT ?opcj ?p ?level ?org ?p3 ?level ?level ?p4 ?slevel WHERE  {   ?opcj ?p ?level  .   ?opcj c2rm:applied_to ?level  .    ?org ?p3 ?level .    ?org c2rm:responsible_for ?level .    ?level ?p4 ?agency .    ?org rdfs:subClassOf ?agency     FILTER(?opcj=cnt:operacao_conjunta) .  }

# %%
rdf_turtle='docs/ieee_grafo_rdf_sparql.ttl'
h=graph_functions.load_turtle_to_graph(rdf_turtle)
graph_functions.visualize_graph_rdf_turtle(h)

# %%
rdf_turtle='docs/corpus_completo_curado_06012025.ttl'
g=graph_functions.load_turtle_to_graph(rdf_turtle)

query = ''
query = 'PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> '
query = query + ' PREFIX c2rm: <http://idea-c2.org/c2rm/#> '
query = query + ' PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> '
query = query + ' PREFIX cnt: <http://idea-c2.org/data/#> '
query = query + ' SELECT DISTINCT ?opcj ?p ?level ?p1 ?docs ?p2 ?t_docs ?org ?p3 ?level '
query = query + ' WHERE '
query = query + ' {'
query = query + '   ?opcj ?p ?level  .'
query = query + '   ?opcj c2rm:applied_to ?level  . '
query = query + '   ?level ?p1 ?docs  . '
query = query + '   ?level c2rm:composed_of ?docs . '
query = query + '   ?docs ?p2 ?t_docs . '
query = query + '   ?docs rdf:Bag ?t_docs .  '
query = query + '   ?org ?p3 ?level . '
query = query + '   ?org c2rm:responsible_for ?level . '
query = query + '   FILTER(REGEX(str(?opcj),"operacao_conjunta")) . '
query = query + ' }'
#query = query + ' LIMIT 1'

# ?s ?p ?o .'
# query = query + '     ?s c2rm:capacity_of ?o .'
# query = query + '     ?s1 rdf:type ?o .'
# query = query + '     FILTER(?s=cnt:agentes_especiais)'

# select=[]
# select[0] = "s p o"
# select

print(query)


xlist=graph_functions.select_grafo3(g, query)
g2=graph_functions.create_subgraph(xlist)
# #graph_functions.visualize_graph_with_networkx(g2)
graph_functions.visualize_graph_rdf_turtle(g2)

# %%
#'docs/corpus_completo_curado_06012025.ttl'

rdf_turtle='docs/corpus_completo_curado_06012025.ttl'
#g=graph_functions.load_turtle_to_graph(rdf_turtle)
#graph_functions.visualize_graph_rdf_turtle(g)

xlist=graph_functions.select_grafo(g,
                                   'PREFIX c2rm: <http://idea-c2.org/c2rm/#> PREFIX cnt: <http://idea-c2.org/data/#> ',
                                   '* ',
                                   '?s rdf:type c2rm:entity; . ?s ?p ?o .  FILTER(REGEX(str(?s),"operacao_de_seguranca"))',
                                   '?s')

query = 'SELECT DISTINCT * '
query = query + ' WHERE '
query = query + ' { ?s rdf:type c2rm:entity; . ?s ?p ?o .  FILTER(REGEX(str(?s),"operacao_ofensiva")) } '
query = query + ' ORDER BY ?s'


xlist=graph_functions.select_grafo2(g, query)
g2=graph_functions.create_subgraph(xlist)
#graph_functions.visualize_graph_with_networkx(g2)
graph_functions.visualize_graph_rdf_turtle(g2)
# Out:
# PREFIX c2rm: <http://idea-c2.org/c2rm/#> PREFIX cnt: <http://idea-c2.org/data/#>
#   SELECT DISTINCT *
#   WHERE
#   { ?s rdf:type c2rm:entity; . ?s ?p ?o .  FILTER(REGEX(str(?s),"operacao_de_seguranca"))
#
#   } ORDER BY ?s
# http://idea-c2.org/data/#operacao_de_seguranca http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://idea-c2.org/c2rm/#entity
# http://idea-c2.org/data/#operacao_de_seguranca http://idea-c2.org/c2rm/#applied_to http://idea-c2.org/data/#inimigo
# http://idea-c2.org/data/#operacao_de_seguranca http://idea-c2.org/c2rm/#applied_to http://idea-c2.org/data/#reconhecimento
# http://idea-c2.org/data/#operacao_de_seguranca http://idea-c2.org/c2rm/#applied_to http://idea-c2.org/data/#seguranca
# SELECT DISTINCT *  WHERE  { ?s rdf:type c2rm:entity; . ?s ?p ?o .  FILTER(REGEX(str(?s),"operacao_ofensiva")) }  ORDER BY ?s
# http://idea-c2.org/data/#operacao_ofensiva http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://idea-c2.org/c2rm/#entity
# ...
