# %% [markdown]
# # ETAPA 3 - RODAR NER - EXPERIMENTO 1 - SCIERC
#
# ## Caderno responsável por extrair as NER dos textos anotados
# ### Passo a passo
# #### 1 - Recuperar as NER anotadas nos textos pelo programa de anotação
# ##### 1.1 - Tags de configuração que estão no item 2.1:
#
# train = "...output/corpus_1_scierc-train0.spacy"
# dev = "...output/corpus_1_scierc-dev0.spacy"
#
# #### 2 - Instanciar o modelo de IA de acordo com os hiperparâmetros.
# ##### 2.1 - Arquivo de configuração dos hiperparâmetros: /content/drive/MyDrive/Doutorado/IDEA/NER/config_spacy.cfg
# #### 3 - Rodar o modelo de aprendizado e avaliar a precisão, a taxa de perda e a acurácia.
# #### 4 - Conforme os resultados de avaliação do modelo, gerar as NER aprendidas.
# ##### 4.1 - Local onde o modelo é gerado: /content/drive/MyDrive/Doutorado/IDEA/NER/outputs
#
# # Data: 18-05-2023
# # Autores: Maj Giselle Farias e Jones.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U spacy
# ********************************************************************
# TEM QUE ESCOLHER BASE OU LARGE
#*********************************************************************
# para utilizar o BERT Base
#!python -m spacy download pt_core_news_sm

# para utilizar o BERT MD
#!python -m spacy download pt_core_news_md

# para utilizar o BERT Large
#!python -m spacy download pt_core_news_lg

# para utilizar o BERT em Inglês Base
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 71.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install spacy-transformers

# %%
# !python -m spacy init fill-config /content/drive/MyDrive/Doutorado/IDEA/NER/config_spacy-EN-CORPUS-1-SCIERC.cfg /content/drive/MyDrive/Doutorado/IDEA/NER/config_spacy-EN-CORPUS-1-SCIERC.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# /content/drive/MyDrive/Doutorado/IDEA/NER/config_spacy-EN-CORPUS-1-SCIERC.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config_spacy-EN-CORPUS-1-SCIERC.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy debug data /content/drive/MyDrive/Doutorado/IDEA/NER/config_spacy-EN-CORPUS-1-SCIERC.cfg
# Out:
# ============================ Data file validation ============================
# config.json: 100% 385/385 [00:00<00:00, 3.56MB/s]
# vocab.txt: 228kB [00:00, 25.4MB/s]
# 2025-12-10 14:50:52.995428: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765378253.017474    8887 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765378253.023949    8887 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python -m spacy train -g 0 /content/drive/MyDrive/Doutorado/IDEA/NER/config_spacy-EN-CORPUS-1-SCIERC.cfg --output /content/drive/MyDrive/Doutorado/IDEA/NER/outputs
# Out:
# ℹ Saving to output directory:
# /content/drive/MyDrive/Doutorado/IDEA/NER/outputs
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# 2025-12-10 14:51:58.956659: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765378318.977822    9293 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765378318.984306    9293 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python -m spacy benchmark accuracy /content/drive/MyDrive/Doutorado/IDEA/NER/outputs/model-last/ /content/drive/MyDrive/preanotetool/output/corpus_1_scierc-test.spacy --gpu-id 0
# Out:
# ℹ Using GPU: 0
# 2025-12-10 17:13:11.751766: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765386791.772705   45657 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765386791.778669   45657 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765386791.794778   45657 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
